# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.linear_model import Ridge
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',100)

data = pd.read_csv('delete3_2.csv', sep=',')

Y1 = data['y1']
Y2 = data['y2']
X = data[['x320', 'x182', 'x61', 'x54', 'x239', 'x244']]

clf1 = Ridge()
clf1.fit(X, Y1)
clf2 = Ridge()
clf2.fit(X, Y2)

x = np.array([0.6895, 270.3794, 369.3962, 61.52, 8.8463, -0.4479]).reshape(1, -1)

result = []
y_pred = clf2.predict(x)
result.append(y_pred)
for i in range(150):
    if x[0][0]<300:
        x[0][0] = x[0][0]+2
    result.append(clf2.predict(x))

result = pd.DataFrame(result)

x1 = pd.DataFrame([89.40 for i in range(151)])
result_end = x1 - result

# %%
result_end.to_csv('调完x320.csv')

# %%
x
# Out:
# array([[300.6895, 270.3794, 369.3962,  61.52  ,   8.8463,  -0.4479]])

# %%
result_2 = []
y_pred = clf2.predict(x)
result_2.append(y_pred)
for i in range(27):
    if x[0][1]>1.5:
        x[0][1] = x[0][1]-10
    result_2.append(clf2.predict(x))
result_2 = pd.DataFrame(result_2)
x1 = pd.DataFrame([89.40 for i in range(28)])
result_2_end = x1 - result_2

# %%
result_2_end.to_csv('调完x320x182.csv')

# %%
x
# Out:
# array([[300.6895,   0.3794, 369.3962,  61.52  ,   8.8463,  -0.4479]])

# %%
result_3 = []
result_3.append(clf2.predict(x))
for i in range(7):
    if x[0][2]>362:
        x[0][2] = x[0][2]-1
    result_3.append(clf2.predict(x))

result_3 = pd.DataFrame(result_3)
x1 = pd.DataFrame([89.40 for i in range(8)])
result_3_end = x1 - result_3
result_3_end.to_csv('调完x320x182x61.csv')

# %%
x
# Out:
# array([[300.6895,   0.3794, 362.3962,  61.52  ,   8.8463,  -0.4479]])

# %%
result_4 = []
y_pred = clf2.predict(x)
result_4.append(y_pred)
for i in range(26):
    if x[0][3]>35:
        x[0][3] = x[0][3]-1
    result_4.append(clf2.predict(x))

result_4 = pd.DataFrame(result_4)
x1 = pd.DataFrame([89.40 for i in range(27)])
result_4_end = x1 - result_4
result_4_end.to_csv('调完x320x182x61x54.csv')

# %%
x
# Out:
# array([[300.6895,   0.3794, 362.3962,  35.52  ,   8.8463,  -0.4479]])

# %%
result_5 = []
y_pred = clf2.predict(x)
result_5.append(y_pred)
for i in range(4):
    if x[0][4]<12:
        x[0][4] = x[0][4]+1
    result_5.append(clf2.predict(x))
x1 = pd.DataFrame([89.40 for i in range(5)])
result_5 = pd.DataFrame(result_5)
result_5_end = x1 - result_5
result_5_end.to_csv('调完x320x182x61x54x239.csv')

# %%
x
# Out:
# array([[300.6895,   0.3794, 362.3962,  35.52  ,  12.8463,  -0.4479]])

# %%
result_6 = []
y_pred = clf2.predict(x)
result_6.append(y_pred)
for i in range(26):
    if x[0][5]<25:
        x[0][5] = x[0][5]+1
    result_6.append(clf2.predict(x))
x1 = pd.DataFrame([89.40 for i in range(27)])
result_6 = pd.DataFrame(result_6)
result_6_end = x1 - result_6
result_6_end.to_csv('调完x320x182x61x54x239x244.csv')

# %%
qwe = pd.read_csv('调完x320.csv', sep=',')

# %%
time = qwe['time']
data_qwe = qwe['data']
# Out:
#      time       data
# 0       0  88.058684
# 1       1  88.060092
# 2       2  88.061501
# 3       3  88.062909
# 4       4  88.064317
# 5       5  88.065726
# 6       6  88.067134
# 7       7  88.068542
# 8       8  88.069951
# 9       9  88.071359
# 10     10  88.072767
# 11     11  88.074176
# 12     12  88.075584
# 13     13  88.076993
# 14     14  88.078401
# 15     15  88.079809
# 16     16  88.081218
# 17     17  88.082626
# 18     18  88.084034
# 19     19  88.085443
# 20     20  88.086851
# 21     21  88.088260
# 22     22  88.089668
# 23     23  88.091076
# 24     24  88.092485
# 25     25  88.093893
# 26     26  88.095301
# 27     27  88.096710
# 28     28  88.098118
# 29     29  88.099527
# 30     30  88.100935
# 31     31  88.102343
# 32     32  88.103752
# 33     33  88.105160
# 34     34  88.106568
# 35     35  88.107977
# 36     36  88.109385
# 37     37  88.110794
# 38     38  88.112202
# 39     39  88.113610
# 40     40  88.115019
# 41     41  88.116427
# ...
