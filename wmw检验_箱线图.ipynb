# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)

data = pd.read_csv('wmw.csv', sep=',')

# %%
data.columns = ["XGB", "组合预测模型", "真实值"]

# %%
x_rf_ridge = data['组合预测模型']
x_xgb = data['XGB']
y = data['真实值']

# %%
from scipy import stats
stats.mannwhitneyu(x_rf_ridge,y,alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=54736.0, pvalue=0.42174568079996944)

# %%
stats.mannwhitneyu(x_xgb,y,alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=54638.0, pvalue=0.4457892728129208)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
data.plot.box()
plt.savefig('test.png')
plt.show()

# %%
xgb_true = data[['XGB', '真实值']]
xgb_true.plot.box()
plt.savefig('xgb.png')
plt.show()

# %%
rf_ridge_true = data[['组合预测模型', '真实值']]
rf_ridge_true.plot.box()
plt.savefig('rf_ridge.png')
plt.show()
